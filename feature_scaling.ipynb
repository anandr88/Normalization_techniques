# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:200%;
#             text-align:center;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700">📏 Normalization 📐 & Standardization📊  Techniques 📏</div>
#
#
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:25px; color:IndianRed"> Feature Scaling </h1>
#
# Feature Scaling is a technique to standardize the independent features present in the data in a fixed range.

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Normalization is the process of changing the values of numbers in a dataset to a common scale.
# <br><br><li>This helps in making sure that no single number or set of numbers dominates the others, while keeping the original differences between the numbers the same.
# <br><br><li>The terms normalization and standardization are sometimes used interchangeably, but they usually refer to different things.
# <br><br><li>The main purpose is to bring all feature values into a similar range to improve the performance and training stability of machine learning models.
# <br><br><li> Normalization (using MinMaxScaler) is always in a range of [0,1] or [-1,1] if there are negative values.
# <br>
# <br>
# <li>Standardization (or Z-score normalization) is that the features will be rescaled to ensure the mean and the standard deviation to be 0 and 1, respectively. Standardization is not bounded by range;
# </div>
# <center><img src="https://www.someka.net/wp-content/uploads/2020/08/difference-between-normalization-standardization-1.png" alt="Heart Disease" width="60%"></center>

# %% [markdown]
# ### Benefits of Normalization:
#
# **Improves Convergence:** Helps gradient descent converge faster in training machine learning models.
#
# **Stability:** Provides numerical stability in algorithms, preventing overflow or underflow.
#
# **Equal Weight:** Ensures that all features contribute equally to the model, preventing dominance by features with larger scales.
#
# **Interpretability:** Makes coefficients in linear models more interpretable.

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Standardization is preferred for algorithms that are sensitive to feature scale (Gradient Descent Based Algorithms) or assume normality, such as linear regression, logistic regression, neural network, PCA (principal component analysis), etc.,
#     <br>
# <br>
# <li>while normalization is better suited for distance-based algorithms like KNN, K-means clustering, and SVM(support vector machines).
#
# </div>

# %% [markdown]
# <font color="IndianRed" size=+2 face="WildWest"><div style="text-align: justify">Difference between Normalization and Standardization</font>
#
# | _S.NO.__ | __Normalization__ | __Standardization__ |
# |------------|-------|------------|
# | 1    | Minimum and maximum value of features are used for scaling  |Mean and standard deviation is used for scaling.      |
# | 2   | It is used when features are of different scales | It is used when we want to ensure zero mean and unit standard deviation      |
# |3   | Scales values between [0, 1] or [-1, 1]. | It is not bounded to a certain range.      |
# |4    | It is really affected by outliers. | It is really affected by outliers.     |
# |5   | Scikit-Learn provides a transformer called MinMaxScaler for normalisation. | Scikit-Learn provides a transformer called StandardScaler for standardization.     |
# | 6   | This transformation squishes the n-dimensional data into an n-dimensional unit hypercube. | It translates the data to the mean vector of original data to the origin and squishes or expands.      |
# |7    | It is useful when we don’t know about the distribution | It is useful when the feature distribution is Normal.      |
# | 8   | It is a often called as Scaling Normalization | It is a often called as Z-Score Normalization.      |

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>There are too many normalization methods are available. Here, we are going to discuss not all the methods but most of them

# %% [markdown]
# <center><img src="https://raw.githubusercontent.com/anandr88/Normalization_techniques/main/narmalization.png" alt="Normalization Methods" width="60%"></center>

# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:150%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"> <span style='color:#CDA63A'>|</span> Different scalers and common misconceptions
# </div>

# %% [markdown]
# <div style="font-family: WildWest; font-size: 25px;line-height: 2; color: IndianRed; text-align: justify">
#     📊👉 <b>Standardization</b> :
#     <ol start="1">
#         <li> <b>Standard Scaler</b>,</li>
#     </ol>
# </div>

# %% [markdown]
# <div style="font-family: WildWest; font-size: 25px; line-height: 2; color: Green; text-align: justify">
#     📈👉 <b>Normalization:</b> :
#     <ol start="2">
#         <li> <b>Min Max Scaling</b>,</li>
#         <li> <b>Robust Scaling</b>,</li>
#         <li> <b>Max Absolute Scaling</b>,</li>
#     </ol>
#     </div>
#     please check:    http://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html#sphx-glr-auto-examples-preprocessing-plot-all-scaling-py

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:45px; color:IndianRed"> 1. Standardization Z-score normalization</h1>
# </div>

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             font-size:130%;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
#     Here, all the features will be trnsformed in such a way that it will have the properties of normal ditribution with mean = 0 and standard devialtion = 1.
# <br>
#     <br>
# <br>
# StandardScaler formula:
#
# $x' = \frac {x-μ}{σ}$
#
# μ - mean
#
# σ - standard deviation
# </div>

# %%
import pandas as pd
import numpy as np

from sklearn.preprocessing import StandardScaler

from sklearn.metrics import roc_auc_score
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
# load the numerical variables of the Titanic Dataset

data = pd.read_csv('titanic.csv', usecols = ['Pclass', 'Age', 'Fare', 'Survived'])
data.head()
# Out:
#    Survived  Pclass   Age   Fare
# 0         0       3  22.0   7.25
# 1         1       1  38.0  71.28
# 2         1       3  26.0   7.92
# 3         1       1  35.0  53.10
# 4         0       3  35.0   8.05

# %%
# let's have a look at the values of those variables to get an idea of the magnitudes
data.describe()
# Out:
#        Survived  Pclass     Age    Fare
# count    891.00  891.00  714.00  891.00
# mean       0.38    2.31   29.70   32.20
# std        0.49    0.84   14.53   49.69
# min        0.00    1.00    0.42    0.00
# 25%        0.00    2.00   20.12    7.91
# 50%        0.00    3.00   28.00   14.45
# 75%        1.00    3.00   38.00   31.00
# max        1.00    3.00   80.00  512.33

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The different variables present different value ranges, therefore different magnitudes. Not only the minimum and maximum values are different, but they also spread over ranges of different widths.
#     </div>

# %%
# let's look at missing data

data.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Age         177
# Fare          0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Age contains missing information, so I will fill those observations with the median in the next cell.

# %%
# let's separate into training and testing set
X_train, X_test, y_train, y_test = train_test_split(data[['Pclass', 'Age', 'Fare']],
                                                    data.Survived, test_size=0.3,
                                                    random_state=0)
X_train.shape, X_test.shape
# Out:
# ((623, 3), (268, 3))

# %%
# let's fill first the missing data

X_train.Age.fillna(X_train.Age.median(), inplace=True)
X_test.Age.fillna(X_train.Age.median(), inplace=True)

# %% [markdown]
# ## <b><span style='color:#E1B12D'>Normalization/standardization before or after train-test split?</span></b>

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>We should never forget that the testing data set represents real-world data.
#     <br>
# <br>
#     <li>So normalize or standardize always AFTER splitting data. If you standardize (take the mean and variance of the whole dataset) before splitting, you'll introduce future information into the training explanatory variables (i.e. the mean and variance).
# </div>

# %%
# standarisation: we use the StandardScaler from sklearn

scaler = StandardScaler() # create an object
X_train_scaled = scaler.fit_transform(X_train) # fit the scaler to the train set, and then transform it

X_test_scaled = scaler.transform(X_test) # transform the test set

# %%
#let's have a look at the scaled training dataset: mean and standard deviation

print('means (Pclass, Age and Fare): ', X_train_scaled.mean(axis=0))
print('std (Pclass, Age and Fare): ', X_train_scaled.std(axis=0))
# Out:
# means (Pclass, Age and Fare):  [4.98976640e-17 1.16903099e-16 5.41746067e-17]
# std (Pclass, Age and Fare):  [1. 1. 1.]

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>As expected, the mean of each variable is now around zero and the standard deviation is set to 1. Thus, all the variable values lie within the same range.
#     </div>

# %%
# let's look at the transformed min and max values

print('Min values (Pclass, Age and Fare): ', X_train_scaled.min(axis=0))
print('Max values (Pclass, Age and Fare): ', X_train_scaled.max(axis=0))
# Out:
# Min values (Pclass, Age and Fare):  [-1.5325562  -2.23351124 -0.67314402]
# Max values (Pclass, Age and Fare):  [0.84844757 3.86209655 9.95192344]

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>However, the minimum and maximum values vary according to how spread the variable was to begin with and is highly influenced by the presence of outliers.
#     <br>
# <br>
#     <li>In data we can observed that the variable Fare has a few extreme outliers, that is, people that paid extraordinarily high Fares.
#         <br>
# <br>
#         <li>Those observations would drive the value of the maximum value far away from the unit variance (a value of 9.9 in this case).
#     </div>

# %%
# let's look at the distribution of the transformed variable Age

plt.hist(X_train_scaled[:,1], bins=20)
# Out:
# (array([ 30.,  10.,  10.,  19.,  52.,  67.,  56., 183.,  56.,  34.,  28.,
#          25.,  18.,  10.,  10.,   7.,   3.,   3.,   1.,   1.]),
#  array([-2.23351124, -1.92873085, -1.62395046, -1.31917007, -1.01438968,
#         -0.70960929, -0.4048289 , -0.10004851,  0.20473188,  0.50951227,
#          0.81429266,  1.11907305,  1.42385344,  1.72863383,  2.03341422,
#          2.33819461,  2.642975  ,  2.94775539,  3.25253577,  3.55731616,
#          3.86209655]),
#  <BarContainer object of 20 artists>)

# %%
# let's look at the distribution of the transformed variable Fare

plt.hist(X_train_scaled[:,2], bins=20)
# Out:
# (array([388., 118.,  54.,  27.,  10.,  12.,   1.,   0.,   7.,   1.,   3.,
#           0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   2.]),
#  array([-0.67314402, -0.14189064,  0.38936273,  0.9206161 ,  1.45186948,
#          1.98312285,  2.51437622,  3.04562959,  3.57688297,  4.10813634,
#          4.63938971,  5.17064309,  5.70189646,  6.23314983,  6.76440321,
#          7.29565658,  7.82690995,  8.35816333,  8.8894167 ,  9.42067007,
#          9.95192344]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The variable Age has a somewhat normal distribution after the transformation, reflecting the approximately Gaussian distribution that shows the original variable.
#     <br>
# <br>
#     <li>Fare on the other had shows a skewed distribution, which is also evidenced after variable transformation in the previous plot.
#         <br>
# <br>
#         <li>In fact, we can see that the standarisation of Fare, shrinks the majority of the observations towards the lowest values.
#     </div>

# %%
import seaborn as sns

# %%
import seaborn as sns
from scipy.stats import pearsonr
import matplotlib.pyplot as plt

# # let's look at how transformed age looks like compared to the original variable
pearson_corr, p_value = pearsonr(X_train['Age'], X_train_scaled[:, 1])
print(f"Pearson correlation coefficient: {pearson_corr:.4f}, p-value: {p_value:.4e}")

sns.jointplot(x=X_train['Age'], y=X_train_scaled[:, 1], kind='kde')

plt.suptitle(f"Pearson correlation: {pearson_corr:.4f}", y=1.05)
plt.show()
# Out:
# Pearson correlation coefficient: 1.0000, p-value: 0.0000e+00

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The transformed variable has a good correlation with the original one.
# </div>

# %%
# let's look at how transformed Fare looks like compared to the original variable

corr, _ = pearsonr(X_train['Fare'], X_train_scaled[:, 2])

# Create the jointplot with KDE
g = sns.jointplot(x=X_train['Fare'], y=X_train_scaled[:, 2], kind='kde', xlim=(0, 200), ylim=(-1, 3))

# Add Pearson correlation coefficient as text
plt.text(0.05, 0.95, f'Pearson r: {corr:.2f}', horizontalalignment='left', verticalalignment='center', transform=g.ax_joint.transAxes)

# Show the plot
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The values are concentrated on the lower left side of the plot, because Fare is highly skewed: the outliers have an influence when computing the empirical mean and standard deviation which shrink the range of the feature values as shown in the left figure above.
#
# </div>

# %%
df = pd.read_csv("titanic.csv", usecols=["Age", "Fare"])
df["Fare"].fillna(value=df["Fare"].mean(), inplace=True)

# %% [markdown]
# # Distribution Visualization

# %%
# importing sklearn StandardScaler class which is for Standardization
from sklearn.preprocessing import StandardScaler

sc = StandardScaler() # creating an instance of the class object
df_new = pd.DataFrame(sc.fit_transform(df), columns=df.columns)  #fit and transforming StandardScaler the dataframe
# plotting the scatterplot of before and after Standardization
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title("Scatterplot Before Standardization", fontsize=18)
sns.scatterplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("Scatterplot After Standardization", fontsize=18)
sns.scatterplot(data = df_new, color="red")
plt.tight_layout()
plt.show()

# %%
# plotting the scatterplot of before and after Standardization
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title("PDF Before Standardization", fontsize=18)
sns.kdeplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("PDF After Standardization", fontsize=18)
sns.kdeplot(data = df_new, color="red")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Notice how the mean of the distribution is very close to 0 and stadard deviation is exactly 1. This is what Standardization does.
# <br>
# <br>
# <li>We had some outliers in Fare and that's why mean didn't reduce down to 0.
# <br>
# <br>
# <li>Also notice that how in the Scatterplot, the scale changed and the distribution came to the centre or 0.
# <br>
# <br>
# <li>In the probability density function, the kde plot is exactly the same, so this shows how the distribution is not effected by standardization

# %% [markdown]
# ## <b><span style='color:#E1B12D'> Is it valid to standardize variables with non-normal distribution?</span></b>

# %% [markdown]
# Once again it is worth highlighting: StandardScaler will not affect data distribution. If you thought it was transforming the distribution of the data, you need to get out of that concept.
#
# It's important to keep in mind that StandardScaler only standardizes the features in the data, it does not enforce a normal distribution.
#
# .
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# <li>There are no possible issues with standardizing non-normal distribution. In other words, if the features do not follow a normal distribution before standardization, they will not follow it after the standardization either (the distribution will remain exactly the same - only the scale will change). So, it’s valid to do it on a non-normal distribution.
#  <br>
# <br>
# <li>Standardization also does not assume anything about the distribution of variables (normal or other).
# <br>
# <br>
# <li>Go ahead and standardize the variables (if required) without worrying about the distribution!
#     <br>
# <br>
# <li>But be careful when a data is highly skewed or have significant outliers (topic discussed later)!
#
# </div>

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:45px; color:IndianRed"> 2. Min-Max Normalization</h1>
# (Minimum and maximum scaling)
# </div>

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             font-size:130%;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# <ul>
# Minimum and maximum scaling squeezes the values between 0 and 1. It subtracts the minimum value from all the observations, and then divides it by the range:
# <br>
#     <br>
# <br>
# MinMaxScaler formula:
#
# $x' =  \frac {x − min(x)}{max(x)-min(x)}$
# </div>

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#CDA63A;
#                                                  color:white;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# It is important to remember that the fit method is used for calculating the mean and variance of each of the features present in our data set. The transform method is transforming all the features using the respective mean and variance.
# </div>

# %%
# this scales the features between 0 and 1.

scaler = MinMaxScaler() # create an instance
X_train_scaled = scaler.fit_transform(X_train) #  fit  the scaler to the train set and then transform it
X_test_scaled = scaler.transform(X_test) # transform (scale) the test set

# %%
#let's have a look at the scaled training dataset: mean and standard deviation

print('means (Pclass, Age and Fare): ', X_train_scaled.mean(axis=0))
print('std (Pclass, Age and Fare): ', X_train_scaled.std(axis=0))
# Out:
# means (Pclass, Age and Fare):  [0.64365971 0.36641321 0.06335433]
# std (Pclass, Age and Fare):  [0.41999093 0.16405255 0.09411705]

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>After MinMaxScaling, the distributions are not centered in zero and the standard deviation is not 1 as when normalising the data.

# %%
# let's look at the new minimum and maximum values

print('Min values (Pclass, Age and Fare): ', X_train_scaled.min(axis=0))
print('Max values (Pclass, Age and Fare): ', X_train_scaled.max(axis=0))
# Out:
# Min values (Pclass, Age and Fare):  [0. 0. 0.]
# Max values (Pclass, Age and Fare):  [1. 1. 1.]

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>But the minimum and maximum values are standarised across variables, different from what occurs with standarisation.

# %%
# let's look at the distributions of the transformed variables: Age

plt.hist(X_train_scaled[:,1], bins=20)
# Out:
# (array([ 30.,  10.,  10.,  19.,  52.,  67.,  56., 183.,  56.,  34.,  28.,
#          25.,  18.,  10.,  10.,   7.,   3.,   3.,   1.,   1.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %%
# let's look at the distributions of the transformed variables: Fare

plt.hist(X_train_scaled[:,2], bins=20)
# Out:
# (array([388., 118.,  54.,  27.,  10.,  12.,   1.,   0.,   7.,   1.,   3.,
#           0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   2.]),
#  array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#         0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  ]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The variable Age has a somewhat normal distribution after the transformation, reflecting the approximately Gaussian distribution that shows the original variable.
#     <br>
# <br>
#     <li>Fare on the other had shows a skewed distribution, which is also evidenced after variable transformation in the previous plot.
#         <br>
# <br>
#     <li>In fact, we can see that the MinMaxScaling of Fare, shrinks the majority of the observations towards the lowest values.

# %%
# let's look at how transformed Age looks like compared to the original variable

corr, _ = pearsonr(X_train['Age'], X_train_scaled[:, 1])

# Create the jointplot with KDE
g = sns.jointplot(x=X_train['Age'], y=X_train_scaled[:, 1], kind='kde')

# Add Pearson correlation coefficient as text
plt.text(0.05, 0.95, f'Pearson r: {corr:.2f}', horizontalalignment='left', verticalalignment='center', transform=g.ax_joint.transAxes)

# Show the plot
plt.show()

# %%
# let's look at how transformed Fare looks like compared to the original variable

corr, _ = pearsonr(X_train['Fare'], X_train_scaled[:, 2])

# Create the jointplot with KDE
g = sns.jointplot(x=X_train['Fare'], y=X_train_scaled[:, 2], kind='kde', xlim=(0, 200), ylim=(-1, 3))

# Add Pearson correlation coefficient as text
plt.text(0.05, 0.95, f'Pearson r: {corr:.2f}', horizontalalignment='left', verticalalignment='center', transform=g.ax_joint.transAxes)

# Show the plot
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>As we can see from the above plot, MinMaxScaler is very sensitive to the presence of outliers.
#     <br>
# <br>
#     <li>It compressed all inliers in the narrow range [0, 0.01] limiting the spread of the variable, and therefore, very likely it would affect the predictive power of this feature.

# %% [markdown]
# # Distribution Visualization

# %%
df = pd.read_csv("titanic.csv", usecols=["Age", "Fare"])
df["Fare"].fillna(value=df["Fare"].mean(), inplace=True)

# %%
# importing sklearn Min Max Scaler class which is for Standardization
from sklearn.preprocessing import MinMaxScaler

mm = MinMaxScaler() # creating an instance of the class object
df_new_mm = pd.DataFrame(mm.fit_transform(df), columns=df.columns)  #fit and transforming MinMaxScaler the dataframe 

# plotting the scatterplot of before and after Min Max Scaling
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title("Scatterplot Before Min Max Scaling", fontsize=18)
sns.scatterplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("Scatterplot After Min Max Scaling", fontsize=18)
sns.scatterplot(data = df_new_mm, color="red")
plt.tight_layout()
plt.show()

# %%
# plotting the scatterplot of before and after Min Max Scaling
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title(" kde plot Before Min Max Scaling", fontsize=18)
sns.kdeplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("kde plot After Min Max Scaling", fontsize=18)
sns.kdeplot(data = df_new_mm, color="red")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:30px; color:IndianRed">Mean-Normalization</h1>

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             font-size:130%;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
#     <li>Mean normalization is very similar to min-max normalization.
#         <br>
# <br>
#
# <li>The difference is instead of the minimum value, the mean value of the column is subtracted in the numerator. The denominator is the same, i.e. the difference between the maximum and the minimum value.
# <br>
# <br>
# Mean-Normalization formula:
#
# $x' =  \frac {x − μ}{max(x)-min(x)}$
#
# mean = μ
#
# <br>
# <br><li>In other words, the mean value of a numerical column is subtracted from each value of the column. And then, the result is used as a numerator.
#
# <br>
# <br><li>Then, the minimum value of the column is subtracted from the maximum value of the column. And the result is used as a denominator.
#
# <br>
# <br><li>We divide the numerator by the denominator and the result is used to replace the value of the column.

# %%
df = pd.read_csv("titanic.csv", usecols=["Age", "Fare"])
df["Fare"].fillna(value=df["Fare"].mean(), inplace=True)

# %%
def mean_normalization(df):
    mean = df.mean()
    min_val = df.min()
    max_val = df.max()
    df_normalized = (df - mean) / (max_val - min_val)
    return df_normalized

# Apply mean normalization
df_new_mm = mean_normalization(df)

# plotting the scatterplot of before and after Min Max Scaling
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title("Scatterplot Before mean normalization Scaling", fontsize=18)
sns.scatterplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("Scatterplot After mean normalization Scaling", fontsize=18)
sns.scatterplot(data = df_new_mm, color="red")
plt.tight_layout()
plt.show()

# %%
# plotting the scatterplot of before and after Min Max Scaling
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title(" PDF Before mean normalization Scaling", fontsize=18)
sns.kdeplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("PDF After mean normalization Scaling", fontsize=18)
sns.kdeplot(data = df_new_mm, color="red")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:40px; color:IndianRed"> 3. Scaling to median and quantiles/ RobustScaler</h1>

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             font-size:130%;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
#     Scaling using median and quantiles consists of substracting the median to all the observations, and then dividing by the interquantile difference. The interquantile difference is the difference between the 75th and 25th quantile:
# <br>
# <br>
# IQR = 75th quantile - 25th quantile
#     <br>
#     <br>
# <br>
# RobustScaler formula:
#
# $x' =  \frac {x − median(x)}{IQR}$
# <br>
# <br>
# IQR - describes the middle 50% of values when ordered from lowest to highest (IQR = Q3 – Q1).
# <br>
# <br>
# The scaled values will have their median and IQR set to 0 and 1, respectively.
# </div>

# %% [markdown]
# ![Interquartile.png](attachment:d1d0c176-f2b7-4025-a138-9d1698c48fef.png)

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             font-size:130%;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
#     <li>Different approach to standardizing input variables in the presence of outliers is to ignore them from the calculation of the mean and standard deviation, then use the calculated values to scale the variable.
#
# <br><br><li>Unlike the previous scalers, the centering and scaling statistics of RobustScaler are based on percentiles and are therefore not influenced by a small number of very large marginal outliers.
#     <br><br><li>Consequently, the resulting range of the transformed feature values is larger than for the previous scalers and, more importantly, are approximately similar.
#
# <br><br><li>The resulting variable is not skewed by outliers and the outliers are still present with the same relative relationships to other values.
#
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             font-size:80%;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# <li> StandardScaler uses mean and standard deviation. RobustScaler uses median and interquartile range (IQR) instead.
# <li> Outliers can significantly alter the mean, but don't affect the median. That’s because the median doesn’t depend on every value in the list.
#     <br>
#     <br>
#     <h5>
#     For an overview of the different scaling methods check: http://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html#sphx-glr-auto-examples-preprocessing-plot-all-scaling-py
# </div>

# %%
# RobustScaler from sklearn performs the above described operation
from sklearn.preprocessing import RobustScaler

# %%
# robust scaler

scaler = RobustScaler() # call the object
X_train_scaled = scaler.fit_transform(X_train) # fit the scaler to the train set, and then scale it
X_test_scaled = scaler.transform(X_test) # scale the test set

# %%
#let's have a look at the scaled training dataset

print('means (Pclass, Age and Fare): ', X_train_scaled.mean(axis=0))
print('std (Pclass, Age and Fare): ', X_train_scaled.std(axis=0))
# Out:
# means (Pclass, Age and Fare):  [-0.47512039  0.0567354   0.7440926 ]
# std (Pclass, Age and Fare):  [0.55998791 1.00109914 2.05514812]

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>As you can see, the distributions are not centered in zero and the standard deviation is not 1 as when normalising the data.

# %%
# let's look at the new minimum and maximum values

print('Min values (Pclass, Age and Fare): ', X_train_scaled.min(axis=0))
print('Max values (Pclass, Age and Fare): ', X_train_scaled.max(axis=0))
# Out:
# Min values (Pclass, Age and Fare):  [-1.33333333 -2.17923077 -0.63931806]
# Max values (Pclass, Age and Fare):  [ 0.          3.92307692 21.19676931]

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Neither are the minimum and maximum values set to a certain upper and lower boundaries like in the MinMaxScaler

# %%
# let's look at the distribution of Age transformed

plt.hist(X_train_scaled[:,1], bins=20)
# Out:
# (array([ 30.,  10.,  10.,  19.,  52.,  67.,  56., 183.,  56.,  34.,  28.,
#          25.,  18.,  10.,  10.,   7.,   3.,   3.,   1.,   1.]),
#  array([-2.17923077, -1.87411538, -1.569     , -1.26388462, -0.95876923,
#         -0.65365385, -0.34853846, -0.04342308,  0.26169231,  0.56680769,
#          0.87192308,  1.17703846,  1.48215385,  1.78726923,  2.09238462,
#          2.3975    ,  2.70261538,  3.00773077,  3.31284615,  3.61796154,
#          3.92307692]),
#  <BarContainer object of 20 artists>)

# %%
# let's look at the distribution of Fare transformed

plt.hist(X_train_scaled[:,2], bins=20)
# Out:
# (array([388., 118.,  54.,  27.,  10.,  12.,   1.,   0.,   7.,   1.,   3.,
#           0.,   0.,   0.,   0.,   0.,   0.,   0.,   0.,   2.]),
#  array([-0.63931806,  0.45248631,  1.54429068,  2.63609505,  3.72789941,
#          4.81970378,  5.91150815,  7.00331252,  8.09511689,  9.18692126,
#         10.27872563, 11.37052999, 12.46233436, 13.55413873, 14.6459431 ,
#         15.73774747, 16.82955184, 17.92135621, 19.01316058, 20.10496494,
#         21.19676931]),
#  <BarContainer object of 20 artists>)

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The variable Age has a somewhat normal distribution after the transformation, reflecting the approximately Gaussian distribution that shows the original variable.
#  <br><br>   <li>Fare on the other had shows a skewed distribution, which is also evidenced after variable transformation in the previous plot.

# %%
# let's look at how transformed Age looks like compared to the original variable

corr, _ = pearsonr(X_train['Age'], X_train_scaled[:, 1])

# Create the jointplot with KDE
g = sns.jointplot(x=X_train['Age'], y=X_train_scaled[:, 1], kind='kde')

# Add Pearson correlation coefficient as text
plt.text(0.05, 0.95, f'Pearson r: {corr:.2f}', horizontalalignment='left', verticalalignment='center', transform=g.ax_joint.transAxes)

# Show the plot
plt.show()

# %%
# let's look at how transformed Fare looks like compared to the original variable

corr, _ = pearsonr(X_train['Fare'], X_train_scaled[:, 2])

# Create the jointplot with KDE
g = sns.jointplot(x=X_train['Fare'], y=X_train_scaled[:, 2], kind='kde', xlim=(0, 200), ylim=(-1, 3))

# Add Pearson correlation coefficient as text
plt.text(0.05, 0.95, f'Pearson r: {corr:.2f}', horizontalalignment='left', verticalalignment='center', transform=g.ax_joint.transAxes)

# Show the plot
plt.show()

# %% [markdown]
#
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>As we can see, The robust scaler does a better job at preserving the spread of the variable after transformation for skewed variables like Fare (compare with the standard scaler or the MinMaxScaler)

# %%
df = pd.read_csv("titanic.csv", usecols=["Age", "Fare"])
df["Fare"].fillna(value=df["Fare"].mean(), inplace=True)

# %%
# importing sklearn Scaler class which is for Robust scaling
from sklearn.preprocessing import RobustScaler

rs = RobustScaler() # creating an instance of the class object
df_new_rs = pd.DataFrame(rs.fit_transform(df), columns=df.columns)  #fit and transforming Robust Scaling the dataframe 

# plotting the scatterplot of before and after Robust Scaling
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title("Scatterplot Before Robust Scaling", fontsize=18)
sns.scatterplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("Scatterplot After Robust Scaling", fontsize=18)
sns.scatterplot(data = df_new_rs, color="red")
plt.tight_layout()
plt.show()

# %%
# plotting the scatterplot of before and after Robust Scaling
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title("PDF Before Robust Scaling", fontsize=18)
sns.kdeplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("PDF After Robust Scaling", fontsize=18)
sns.kdeplot(data = df_new_rs, color="red")
plt.tight_layout()
plt.show()

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:50px; color:IndianRed"> 4. Max Absolute Scaling</h1>

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             font-size:130%;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
#     <ul>
# <li>Scale each feature by its maximum absolute value.
# <br>
#    <br><br><li>This estimator scales and translates each feature individually such that the maximal absolute value of each feature in the training set will be 1.0. It does not shift/center the data, and thus does not destroy any sparsity.
# <br>
#     <br><br><li>The Max-Abs scaling method works by making sure that the training data lies within the range  by applying the following formula:
#     <br><br><br>
#         $X_s' =  \frac {X}{max(abs|X|)}$
#
# <br>
#     <br><br><li>This scaler can also be applied to sparse CSR (Compressed Sparse Row) or CSC (Compressed Sparse Column) matrices.

# %%
df = pd.read_csv("titanic.csv", usecols=["Age", "Fare"])
df["Fare"].fillna(value=df["Fare"].mean(), inplace=True)

# %%
# importing sklearn Min Max Scaler class which is for Max Absolute Scaling
from sklearn.preprocessing import MaxAbsScaler

ma = MaxAbsScaler() # creating an instance of the class object
df_new_ma = pd.DataFrame(ma.fit_transform(df), columns=df.columns)  #fit and transforming Max Absolute Scaling the dataframe

# %%
# plotting the scatterplot of before and after Max Absolute Scaling
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title("Scatterplot Before Max Absolute Scaling", fontsize=18)
sns.scatterplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("Scatterplot After Max Absolute Scaling", fontsize=18)
sns.scatterplot(data = df_new_ma, color="red")
plt.tight_layout()
plt.show()

# %%
# plotting the scatterplot of before and after max Absolute Scaling
plt.figure(figsize=(14,7))
plt.subplot(1,2,1)
plt.title("PDF Before Max Absolute Scaling", fontsize=18)
sns.kdeplot(data = df, color="blue")
plt.subplot(1,2,2)
plt.title("PDF After Max Absolute Scaling", fontsize=18)
sns.kdeplot(data = df_new_ma, color="red")
plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Max Absolute scaling will perform a lot better in sparse data or when most of the values are 0.

# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:150%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> One more example (and comparison)</div>

# %% [markdown]
#
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Let's create a new data set: 60 random points from normal distribution with mean = 5 and standard deviation = 8

# %%
data = np.random.normal(5, 8, 60)
new_df = pd.DataFrame({"Data":data})

# %%
new_df.describe()
# Out:
#             Data
# count  60.000000
# mean    5.121069
# std     8.275292
# min   -13.623753
# 25%     0.021942
# 50%     4.163204
# 75%    10.507832
# max    27.044199

# %%
fig = plt.figure(figsize = (20,6))

ax = sns.histplot(new_df, color='#008080', kde=True, bins=60)
ax.set(title = "Dataframe without outliers")
ax.legend([],[], frameon=False)
ax.axvline(new_df['Data'].median(), color='red', ls='--', lw=2)
ax.axvline(new_df['Data'].mean(), color='blue', ls='--', lw=2)

plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Now we add a few outliers to our input list.

# %%
outliers = np.random.uniform(200, 150, 5)
out_df = pd.DataFrame({"Data": np.append(new_df, outliers)})

# %%
out_df.describe()
# Out:
#              Data
# count   65.000000
# mean    18.016718
# std     45.859446
# min    -13.623753
# 25%      0.677149
# 50%      4.439289
# 75%     13.280428
# max    190.633389

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Outliers caused the mean to increase significantly! Median, however, increased by a minimal amount.

# %%
fig = plt.figure(figsize = (20,6))

ax = sns.histplot(out_df, color='#008080', kde=True, bins=60)
ax.set(title = "Dataframe with outliers")
ax.legend([],[], frameon=False)
ax.axvline(out_df['Data'].median(), color='red', ls='--', lw=2)
ax.axvline(out_df['Data'].mean(), color='blue', ls='--', lw=2)

plt.show()

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler

# Creating functions for scaling
def Standard_Scaler (df, col_names):
    features = df[col_names]
    scaler = StandardScaler().fit(features.values)
    features = scaler.transform(features.values)
    df[col_names] = features
    return df

def MinMax_Scaler (df, col_names):
    features = df[col_names]
    scaler = MinMaxScaler().fit(features.values)
    features = scaler.transform(features.values)
    df[col_names] = features
    return df

def Robust_Scaler (df, col_names):
    features = df[col_names]
    scaler = RobustScaler().fit(features.values)
    features = scaler.transform(features.values)
    df[col_names] = features
    return df

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#CDA63A;
#                                                  color:white;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# It is important to remember that the fit method is used for calculating the mean and variance of each of the features present in our data set. The transform method is transforming all the features using the respective mean and variance. In this cose we transform the entire data set without splitting, but when we perform train-test split we have to remember that fit and transform is for train and transform for test set.
# </div>

# %%
df_robust = out_df.copy()
df_stand = out_df.copy()
df_norm = out_df.copy()

df_robust = Robust_Scaler (df_robust, col_names)
df_stand = Standard_Scaler (df_stand, col_names)
df_norm = MinMax_Scaler (df_norm, col_names)

df_robust2 = new_df.copy()
df_stand2 = new_df.copy()
df_norm2 = new_df.copy()

df_robust2 = Robust_Scaler (df_robust2, col_names)
df_stand2 = Standard_Scaler (df_stand2, col_names)
df_norm2 = MinMax_Scaler (df_norm2, col_names)

# %%
fig = plt.figure(figsize = (20,10))

plt.subplot(2,3,1)
ax = sns.histplot(df_stand2["Data"], color='#008080', fill= True, alpha=.7, kde=True)
ax.set(title = "StandardScaler")
ax.set_xlabel(' ')

plt.subplot(2,3,2)
ax = sns.histplot(df_norm2["Data"], color='#FF6347', fill= True, alpha=.7, kde=True)
ax.set(title = "MinMaxScaler")
ax.set_xlabel(' ')

plt.subplot(2,3,3)
ax = sns.histplot(df_robust2["Data"], color='#FBDD7E', fill= True, alpha=.7, kde=True)
ax.set(title = "RobustScaler")
ax.set_xlabel(' ')

plt.subplot(2,3,4)
ax = sns.histplot(df_stand["Data"], color='#008080', fill= True, alpha=.7, kde=True)
ax.set(title = "StandardScaler")
ax.set_xlabel(' ')

plt.subplot(2,3,5)
ax = sns.histplot(df_norm["Data"], color='#FF6347', fill= True, alpha=.7, kde=True)
ax.set(title = "MinMaxScaler")
ax.set_xlabel(' ')

plt.subplot(2,3,6)
ax = sns.histplot(df_robust["Data"], color='#FBDD7E', fill= True, alpha=.7, kde=True)
ax.set(title = "RobustScaler")
ax.set_xlabel(' ')

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info" style="background-color:#CDA63A;
#                                                  color:white;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# RobustScaler produces a much wider range of values than the StandardScaler.
#
#        That is expected. But wait a second - don't we expect the range of the transformed features to be also approximately similar?
#
# We can see that there is a significant difference when we compare scaled data with and without outliers. The difference is much lower with StandardScaler. So which scaler is the best in the end?
# </div>

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             font-size:120%;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# It is very important to highlight here that RobustScaler's results are not skewed by outliers and the spread represents REAL distance. It is more consistent with non-scaled data, even though it doesn't look like it at first glance.
#
# * Remember that StandardScaler is also sensitive to outliers (less than MinMaxScaler, but still sensitive). The mean and standard deviation are highly affected by outliers. As a result the distance (measured in standard deviation) is also affected by outliers.
#
# * The spread of values after robust scaling is much higher, but there are only a few values with big distance (outliers) while the others are much closer. This is reality and the algorithm will be no mislead by this situation. On the contrary - it should work better.
# </div>

# %% [markdown]
# ## <b> <span style='color:#E1B12D'>Is it always better to use the RobustScaler?</span></b>

# %% [markdown]
# When analyzing data, it's important to consider the amount of information that can be extracted from it. Robust measures like the interquartile range (IQR) are designed to focus on a specific subset of the data while ignoring potentially unreliable values. However, this deliberate exclusion of certain data can limit the overall amount of information that is used to make predictions, leading to lower confidence of the result.
#
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# Personally I would take advantage of StandardScaler if:
#
# * I decided to delete outliers or they are not present in a data set
# * When the data is not very highly skewed.
#
# I would use RobustScaler in opposite situations.
# </div>

# %% [markdown]
# ## <b><span style='color:#E1B12D'>Best practices</span></b>

# %% [markdown]
# <div style=" background-color:#3b3745;
#             text-align:left;
#             padding: 13px 13px;
#             border-radius: 8px;
#             margin: auto;
#             color: white">
# <ul>
# <li> It’s usually a bad idea to train machine learning models on features with vastly different scales.
# <li> Consider deleting outliers before scaling a data, but be very careful when a data is highly imbalanced.
# <li> Some machine learning algorithms are sensitive to feature scaling (gradient descent, distance based) while others are not (tree-based).
# <li> Normalize or standardize always AFTER splitting data (of course you need to apply normalization/standardization to test data as well).
# <li> StandardScaler, MinMaxScaler and RobustScaler will not affect data distribution (the algorithms don't enforce a normal distribution).
#
# <li> Normalisation does not treat outliers well (MinMax Scaler shrinks the data within the given range which will affect the ability of the algorithm to give adequate weights for the features).
# <li> MinMaxScaler can be used when the upper and lower boundaries are well known from domain knowledge.
#
# <li> Standardization allows better handling of the outliers and better facilitates convergence of features (which is important for the gradient descent and distance based algorithms).
# <li> StandardScaler is also sensitive to outliers (less than MinMaxScaler, but still sensitive). The mean and standard deviation are highly affected by outliers so the distance (measured in standard deviation) is also affected by outliers - the algorithm will scale most of the data to a small interval.
# <li> RobustScaler's results are not skewed by outliers and the spread represents REAL distance.
# <li> RobustScaler's deliberate exclusion of certain data can limit the overall amount of information that is used to make predictions, leading to lower confidence of the result.
# <li> In my opinion there are no possible issues with standardizing non-normal distribution.
#
# <li> You can always start by fitting your model to raw, normalized and standardized data and compare the performance for best results.
#
# ***
#
# <b>I usually prefer standardization over normalization.
#
# I would take advantage of StandardScaler if:
#
# * I decide to delete outliers or they are not present in a data set;
# * when the data is not very highly skewed.
#
# I would use RobustScaler in opposite situations and MinMaxScaler only in a very special cases.
#
# </ul>
# </div>

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5642C5;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Model Building</b>
#         </p>
# </div>

# %%
df = pd.read_csv('winequality_red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9       0.08
# 1            7.8              0.88         0.00             2.6       0.10
# 2            7.8              0.76         0.04             2.3       0.09
# 3           11.2              0.28         0.56             1.9       0.07
# 4            7.4              0.70         0.00             1.9       0.08
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0      1.0  3.51       0.56
# 1                 25.0                  67.0      1.0  3.20       0.68
# 2                 15.0                  54.0      1.0  3.26       0.65
# 3                 17.0                  60.0      1.0  3.16       0.58
# 4                 11.0                  34.0      1.0  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
Q1 = df.quantile(0.15)
Q3 = df.quantile(0.85)
IQR = Q3 - Q1
IQR.sort_values(ascending=False)
# Out:
# total sulfur dioxide    6.50e+01
# free sulfur dioxide     2.10e+01
# fixed acidity           3.40e+00
# alcohol                 2.20e+00
# residual sugar          1.16e+00
# quality                 1.00e+00
# citric acid             4.60e-01
# volatile acidity        3.51e-01
# pH                      3.00e-01
# sulphates               2.80e-01
# chlorides               3.50e-02
# density                 3.60e-03
# dtype: float64

# %%
wine1 = df [~((df < (Q1 - 1.5 * IQR)) |(df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
X = wine1.drop(['quality'],axis=1) 
y = wine1['quality']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=.20,random_state=21)

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:25px; color:IndianRed">Without Scaling</h1>

# %% [markdown]
# ### LogisticRegression

# %%
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay
from sklearn.linear_model import LogisticRegression

# Logistic Regression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred_lr = logreg.predict(X_test)

log_train = round(logreg.score(X_train, y_train) * 100, 2)
log_accuracy_without_scaling = round(accuracy_score(y_pred_lr, y_test) * 100, 2)

print("Training Accuracy    :", log_train, "%")
print("Model Accuracy Score :", log_accuracy_without_scaling, "%")
# Out:
# Training Accuracy    : 60.2 %
# Model Accuracy Score : 56.74 %

# %% [markdown]
# ### SVM

# %%
# Support Vector Machines
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)
y_pred_svc = svc.predict(X_test)

svc_train = round(svc.score(X_train, y_train) * 100, 2)
svc_accuracy_without_scaling = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :",svc_train ,"%")
print("Model Accuracy Score :",svc_accuracy_without_scaling ,"%")
# Out:
# Training Accuracy    : 51.6 %
# Model Accuracy Score : 50.0 %

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:25px; color:IndianRed">Normalization or Minmax Scaling</h1>

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train_minmax = pd.DataFrame(X_train, columns=X.columns)
X_test_minmax = pd.DataFrame(X_test, columns=X.columns)

# %% [markdown]
# ### Logistic Regression

# %%
### from sklearn.metrics import accuracy_score,classification_report,confusion_matrix,plot_confusion_matrix,plot_roc_curve,plot_precision_recall_curve

from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_minmax, y_train)
y_pred_lr = logreg.predict(X_test_minmax)

log_train = round(logreg.score(X_train_minmax, y_train) * 100, 2)
log_accuracy_MinMax = round(accuracy_score(y_pred_lr, y_test) * 100, 2)

print("Training Accuracy    :",log_train ,"%")
print("Model Accuracy Score :",log_accuracy_MinMax ,"%")
# Out:
# Training Accuracy    : 63.39 %
# Model Accuracy Score : 59.93 %

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train_minmax, y_train)
y_pred_svc = svc.predict(X_test_minmax)

svc_train = round(svc.score(X_train_minmax, y_train) * 100, 2)
svc_accuracy_MinMax = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :",svc_train ,"%")
print("Model Accuracy Score :",svc_accuracy_MinMax ,"%")
# Out:
# Training Accuracy    : 67.64 %
# Model Accuracy Score : 64.18 %

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:25px; color:IndianRed">StandardScaler</h1>

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train_standard = pd.DataFrame(X_train, columns=X.columns)
X_test_standard = pd.DataFrame(X_test, columns=X.columns)

# %% [markdown]
# ### Logistic Regression

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_standard, y_train)
y_pred_lr = logreg.predict(X_test_standard)

log_train = round(logreg.score(X_train_standard, y_train) * 100, 2)
log_accuracy_std = round(accuracy_score(y_pred_lr, y_test) * 100, 2)

print("Training Accuracy    :",log_train ,"%")
print("Model Accuracy Score :",log_accuracy_std ,"%")
# Out:
# Training Accuracy    : 63.21 %
# Model Accuracy Score : 59.57 %

# %% [markdown]
# ## Support Vector Machines

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train_standard, y_train)
y_pred_svc = svc.predict(X_test_standard)

svc_train = round(svc.score(X_train_standard, y_train) * 100, 2)
svc_accuracy_std = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :",svc_train ,"%")
print("Model Accuracy Score :",svc_accuracy_std ,"%")
# Out:
# Training Accuracy    : 69.77 %
# Model Accuracy Score : 63.48 %

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:25px; color:IndianRed">RobustScaler</h1>

# %%
from sklearn.preprocessing import RobustScaler
scaler = RobustScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train_robust = pd.DataFrame(X_train, columns=X.columns)
X_test_robust = pd.DataFrame(X_test, columns=X.columns)

# %% [markdown]
# ### Logistic Regression

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_robust, y_train)
y_pred_lr = logreg.predict(X_test_robust)

log_train = round(logreg.score(X_train_robust, y_train) * 100, 2)
log_accuracy_Robust = round(accuracy_score(y_pred_lr, y_test) * 100, 2)

print("Training Accuracy    :",log_train ,"%")
print("Model Accuracy Score :",log_accuracy_Robust ,"%")
# Out:
# Training Accuracy    : 63.21 %
# Model Accuracy Score : 59.57 %

# %% [markdown]
# ### Support Vector Machines

# %%
# Support Vector Machines
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train_robust, y_train)
y_pred_svc = svc.predict(X_test_robust)

svc_train = round(svc.score(X_train_robust, y_train) * 100, 2)
svc_accuracy_Robust = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :",svc_train ,"%")
print("Model Accuracy Score :",svc_accuracy_Robust ,"%")
# Out:
# Training Accuracy    : 70.04 %
# Model Accuracy Score : 63.48 %

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:25px; color:IndianRed">Max Absolute Scaling</h1>

# %%
from sklearn.preprocessing import MaxAbsScaler
scaler = MaxAbsScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

X_train_MaxAbs = pd.DataFrame(X_train, columns=X.columns)
X_test_MaxAbs = pd.DataFrame(X_test, columns=X.columns)

# %% [markdown]
# ### Logistic Regression

# %%
# Logistic Regression
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train_MaxAbs, y_train)
y_pred_lr = logreg.predict(X_test_MaxAbs)

log_train = round(logreg.score(X_train_MaxAbs, y_train) * 100, 2)
log_accuracy_MaxAbs = round(accuracy_score(y_pred_lr, y_test) * 100, 2)

print("Training Accuracy    :",log_train ,"%")
print("Model Accuracy Score :",log_accuracy_MaxAbs ,"%")
# Out:
# Training Accuracy    : 63.03 %
# Model Accuracy Score : 59.57 %

# %% [markdown]
# ### Support Vector Machines

# %%
# Support Vector Machines
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train_MaxAbs, y_train)
y_pred_svc = svc.predict(X_test_MaxAbs)

svc_train = round(svc.score(X_train_MaxAbs, y_train) * 100, 2)
svc_accuracy_MaxAbs = round(accuracy_score(y_pred_svc, y_test) * 100, 2)

print("Training Accuracy    :",svc_train ,"%")
print("Model Accuracy Score :",svc_accuracy_MaxAbs ,"%")
# Out:
# Training Accuracy    : 68.71 %
# Model Accuracy Score : 62.06 %

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:25px; color:IndianRed">Comparing Different Models with different Scaling</h1>

# %%
models = pd.DataFrame({
    'Model': [
        'LogisticRegression without Scaling','SVM without Scaling',
        'LogisticRegression with MinMax Scaling','SVM with MinMax Scaling',
        'LogisticRegression with StandardScaler Scaling','SVM with StandardScaler Scaling',
        'LogisticRegression with RobustScaler Scaling','SVM with RobustScaler Scaling',
        'LogisticRegression with MaxAbs Scaling','SVM with MaxAbs Scaling'
    ],
    'Model Accuracy Score': [
        log_accuracy_without_scaling, svc_accuracy_without_scaling, 
        log_accuracy_MinMax, svc_accuracy_MinMax,
        log_accuracy_std, svc_accuracy_std,
        log_accuracy_Robust, svc_accuracy_Robust,
        log_accuracy_MaxAbs, svc_accuracy_MaxAbs
    ]
})

# %%
import pandas as pd

# Set the precision for floating-point numbers
pd.set_option('display.precision', 2)

# Assuming models is your DataFrame
styled_df = models.sort_values(by='Model Accuracy Score', ascending=False).style.background_gradient(
    cmap='coolwarm').hide_index().set_properties(**{
        'font-family': 'Lucida Calligraphy',
        'color': 'black',
        'font-size': '15px'
    })

styled_df
# Out:
# <style type="text/css">
# #T_c2103_row0_col0, #T_c2103_row1_col0, #T_c2103_row2_col0, #T_c2103_row3_col0, #T_c2103_row4_col0, #T_c2103_row5_col0, #T_c2103_row6_col0, #T_c2103_row7_col0, #T_c2103_row8_col0, #T_c2103_row9_col0 {
#   font-family: Lucida Calligraphy;
#   color: black;
#   font-size: 15px;
# }
# #T_c2103_row0_col1 {
#   background-color: #b40426;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: black;
#   font-size: 15px;
# }
# #T_c2103_row1_col1, #T_c2103_row2_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: black;
#   font-size: 15px;
# }
# #T_c2103_row3_col1 {
#   background-color: #e36c55;
#   color: #f1f1f1;
#   font-family: Lucida Calligraphy;
#   color: black;
#   font-size: 15px;
# }
# #T_c2103_row4_col1 {
#   background-color: #f7ac8e;
#   color: #000000;
#   font-family: Lucida Calligraphy;
#   color: black;
#   font-size: 15px;
# }
# ...

# %% [markdown]
# <div style="padding:30px;
#             color:white;
#             margin:10;
#             font-size:180%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:800"><span style='color:#CDA63A'>|</span>Gaussian Transformation</div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>Some machine learning models like linear and logistic regression assume that the variables are normally distributed.
#     <br>Others benefit from "Gaussian-like" distributions, as in such distributions the observations of X available to predict Y vary across a greater range of values.
#     <br>Thus, Gaussian distributed variables may boost the machine learning algorithm performance.
#
# If a variable is not normally distributed, sometimes it is possible to find a mathematical transformation so that the transformed variable is Gaussian.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#             font-size:120%;
#            border-radius:5px;
#            background-color:#A9C9A9;
#            font-size:16px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 8px;
#               color:black;">How can we transform variables so that they follow a Gaussian distribution?
#
# There are a few straightforward methods to transform variables so that they follow a Gaussian distribution. None of them is better than the other, they rather depend on the original distribution of the variables. They are:
#
#     * a. Logarithmic Transformation
#     * b. Reciprocal Transformation
#     * c. Square Root Transformation
#     * d. Exponential Transformation
#     * e. Box Cox Transformation
# To understand how the boxcox transformation works, please refer to these links:
#
# http://www.statisticshowto.com/box-cox-transformation/
# http://www.itl.nist.gov/div898/handbook/eda/section3/eda336.htm
# http://onlinestatbook.com/2/transformations/box-cox.html

# %%
# load the numerical variables of the Titanic Dataset

data = pd.read_csv('titanic.csv', usecols = ['Age', 'Fare', 'Survived'])
data.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %% [markdown]
# ### Fill missing data with random sample

# %%
# first I will fill the missing data of the variable age, with a random sample of the variable

def impute_na(data, variable):
    # function to fill na with a random sample
    df = data.copy()
    
    # random sampling
    df[variable+'_random'] = df[variable]
    
    # extract the random sample to fill the na
    random_sample = df[variable].dropna().sample(df[variable].isnull().sum(), random_state=0)
    
    # pandas needs to have the same index in order to merge datasets
    random_sample.index = df[df[variable].isnull()].index
    df.loc[df[variable].isnull(), variable+'_random'] = random_sample
    
    return df[variable+'_random']

# %%
# fill na
data['Age'] = impute_na(data, 'Age')

# %% [markdown]
# # Age
#
# ## Original distribution
# ### .
#
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
#
# <li>To visualise the distribution of the variable, Age in this case, we plot a histogram to visualise a bell-shape, and the Q-Qplot.
#     <li>Remember that if the variable is normally distributed, we should see a 45 degree straight line of the values over the theoretical quantiles.

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import pylab

# %%
# plot the histograms to have a quick look at the distributions
# we can plot Q-Q plots to visualise if the variable is normally distributed

def diagnostic_plots(df, variable):
    # function to plot a histogram and a Q-Q plot
    # side by side, for a certain variable
    
    plt.figure(figsize=(15,6))
    plt.subplot(1, 2, 1)
    df[variable].hist()

    plt.subplot(1, 2, 2)
    stats.probplot(df[variable], dist="norm", plot=pylab)

    plt.show()
    
diagnostic_plots(data, 'Age')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The variable Age is almost normally distributed, except for some observations on the lower value tail of the distribution.
#
# <li>Note the slight skew to the left in the histogram, and the deviation from the straight line towards the lower values ont he Q-Q- plot.
#
# <li>In the following cells, I will apply the above mentioned transformations and compare the distributions of the transformed Age.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Logarithmic Transformation</b>
#         </p>
# </div>

# %%
### Logarithmic transformation
data['Age_log'] = np.log(data.Age)

diagnostic_plots(data, 'Age_log')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li> The logarithmic transformation, did not render a Gaussian like distribution for Age.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Reciprocal transformation</b>
#         </p>
# </div>

# %%
### 
data['Age_reciprocal'] = 1 / data.Age

diagnostic_plots(data, 'Age_reciprocal')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li> The reciprocal transformation was also not useful to transform Age into a variable normally distributed.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Square root transformation</b>
#         </p>
# </div>

# %%
data['Age_sqr'] =data.Age**(1/2)

diagnostic_plots(data, 'Age_sqr')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li> The square root transformation is a bit more succesful that the previous 2 transformations, however, the variable is still notGaussian, and this does not represent an improvement towards normality respect the original distribution of Age.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Exponential</b>
#         </p>
# </div>

# %% [markdown]
# <h1 style="text-align: justify; font-family: 'WildWest'; font-size:25px; color:IndianRed">d. Exponential</h1>

# %%
data['Age_exp'] = data.Age**(1/1.2) # you can vary the exponent as needed

diagnostic_plots(data, 'Age_exp')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The exponential transformation is the best of all the transformations above, at the time of generating a variable that is normally distributed.
#     <li>Comparing the histogram and Q-Q plot of the exponentially transformed Age with the original distribution, I would say that by visual inspection the transformed variable follows more closely a Gaussian distribution.
# </div>
#
# # Should I transform the variable?
#
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>It depends on what we are trying to achieve. If this was a situation in a business setting, I would use the original variable without transformation to train the model, as this would represent a simpler situation at the time of asking developers to implement the model in real life, and also it will be easier to interpret.
#     <li>If on the other hand this was an exercise to win a data science competition, I would opt to use the variable that gives me the highest performance.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>BoxCox transformation</b>
#         </p>
# </div>

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  font-size:120%;
#                                                  text-align: left;">
# <li>BoxCox transformation
#
# <li>The Box-Cox transformation is defined as:
#
# T(Y)=(Y exp(λ)−1)/λ
#
# <li>where Y is the response variable and λ is the transformation parameter. λ varies from -5 to 5. In the transformation, all values of λ are considered and the optimal value for a given variable is selected.
#
# <li>Briefly, for each λ (the transformation tests several λs), the correlation coefficient of the Probability Plot (Q-Q plot below, correlation between ordered values and theoretical quantiles) is calculated.
#
# <li>The value of λ corresponding to the maximum correlation on the plot is then the optimal choice for λ.
#
# <li>In python, we can evaluate and obtain the best λ with the stats.boxcox function from the package scipy.
#
# Let's have a look.

# %%
data['Age_boxcox'], param = stats.boxcox(data.Age) 

print('Optimal λ: ', param)

diagnostic_plots(data, 'Age_boxcox')
# Out:
# Optimal λ:  0.7648522500282625

# %% [markdown]
# # Fare
#
# ## Original distribution

# %%
diagnostic_plots(data, 'Fare')

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Logarithmic transformation</b>
#         </p>
# </div>

# %%
### Logarithmic transformation
data['Fare_log'] = np.log(data.Fare+1) # We don't want log of 0

diagnostic_plots(data, 'Fare_log')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The logarithmic transformation does a good job to make the variable Fare look more Gaussian. The histogram still shows signs of skewness and some observations deviate from the 45 degree line on the Q-Q plot, but by all means it is much more Gaussian looking than the original variable.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Reciprocal transformation</b>
#         </p>
# </div>

# %%
### Reciprocal transformation
data['Fare_reciprocal'] = 1 / (data.Fare+1)

diagnostic_plots(data, 'Fare_reciprocal')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The reciprocal transformation, on the other hand, is not useful to make Fare less skewed.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Square root transformation</b>
#         </p>
# </div>

# %%
data['Fare_sqr'] =data.Fare**(1/2)

diagnostic_plots(data, 'Fare_sqr')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The square root transformation is not useful to make Fare more Gaussian looking.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>Exponential</b>
#         </p>
# </div>

# %%
data['Fare_exp'] =data.Fare**(1/5)

diagnostic_plots(data, 'Fare_exp')

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>The exponential transformation works better than the last 2, perhaps as well as the logarithmic transformation.

# %% [markdown]
# <div style="color:white;
#            display:fill;
#            border-radius:5px;
#            background-color:#5F1666;
#            font-size:33px;
#            font-family:Nexa;
#            letter-spacing:0.5px">
#         <p style="padding: 15px;
#               color:white;">
#             <b>BoxCox transformation</b>
#         </p>
# </div>

# %%
data['Fare_boxcox'], param = stats.boxcox(data.Fare+1) # you can vary the exponent as needed

print('Optimal lambda: ', param)

diagnostic_plots(data, 'Fare_boxcox')
# Out:
# Optimal lambda:  -0.09778702818680361

# %% [markdown]
# <div class="alert alert-block alert-info" style="
#                                                  color:black;
#                                                  font-size:120%;
#                                                  border-color:black;
#                                                  border-radius:5px;
#                                                  width:100%;
#                                                  margin: auto;
#                                                  text-align: left;">
# <li>We can see that after the transformation, the quantiles are somewhat more aligned over the 45 degree line with the theoreical quantiles of the Gaussian distribution.
# <li>For Fare, we could use the logarithmic, exponential or Box-Cox transformation to shape the variable into a transformed version that follows more closely (albeit not perfectly) a normal distribution.
#     <li>It is very likely that this transformation would improve the performance of many machine learning models, respect to using the variable Fare without transformation.
#         <li>Go ahead and test this transformation on a few machine learning algorithms, using the original Fare and the transformed version for comparison.

# %% [markdown]
# <div style="padding:20px;
#             color:white;
#             margin:10;
#             font-size:150%;
#             text-align:left;
#             display:fill;
#             border-radius:5px;
#             background-color:#294B8E;
#             overflow:hidden;
#             font-weight:700"><span style='color:#CDA63A'>|</span> References</div>

# %% [markdown]
# https://proclusacademy.com/blog/robust-scaler-outliers/
#
# https://scikit-learn.org/stable/auto_examples/preprocessing/plot_all_scaling.html
#
# https://www.youtube.com/watch?v=mnKm3YP56PY&list=PLZoTAELRMXVMhVyr3Ri9IQ-t5QPBtxzJO&index=16
#
# https://www.youtube.com/watch?v=BotYLBQfd5M
#
# https://github.com/venkatreddy09/Feature-Engineering/blob/master/
#
# https://www.kaggle.com/code/aimack/complete-guide-to-feature-scaling
